# %% [markdown]
# # 01 - Chargement des Données
#
# Ce notebook charge et explore rapidement le dataset de détection de fraude.

# %% [markdown]
# ## 1. Import des librairies

# %%
# Librairies de manipulation de données
import pandas as pd
import numpy as np

# Configuration de l'affichage
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)

print("✓ Librairies importées avec succès")
# Out:
# ✓ Librairies importées avec succès

# %% [markdown]
# ## 2. Chargement des données

# %%
# Chemin vers le fichier de données
data_path = '../data/raw/fraud_synth_10000.csv'

# Chargement du fichier CSV
df = pd.read_csv(data_path)

print(f"✓ Données chargées : {df.shape[0]} lignes, {df.shape[1]} colonnes")
# Out:
# ✓ Données chargées : 10000 lignes, 9 colonnes

# %% [markdown]
# ## 3. Aperçu rapide des données

# %%
# Afficher les 5 premières lignes
print("📊 Premières lignes du dataset :")
df.head()
# Out:
# 📊 Premières lignes du dataset :
#    transaction_amount  transaction_hour  num_transactions_24h  \
# 0               15.01                17                     3
# 1               24.67                13                     2
# 2               92.79                13                     4
# 3               38.67                22                     6
# 4               69.14                10                     3
#
#    account_age_days  avg_amount_30d country_risk device_type  \
# 0              3615           15.68          low      mobile
# 1               209           49.99          low      mobile
# 2               438           10.65          low      mobile
# 3              1830            9.62          low     desktop
# 4              1686           21.91       medium      mobile
#
#    is_foreign_transaction  fraud
# 0                       1      0
# 1                       0      0
# 2                       0      0
# 3                       1      0
# ...

# %%
# Informations sur les colonnes et types de données
print("📋 Informations sur le dataset :")
df.info()
# Out:
# 📋 Informations sur le dataset :
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 9 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   transaction_amount      10000 non-null  float64
#  1   transaction_hour        10000 non-null  int64
#  2   num_transactions_24h    10000 non-null  int64
#  3   account_age_days        10000 non-null  int64
#  4   avg_amount_30d          10000 non-null  float64
#  5   country_risk            10000 non-null  object
#  6   device_type             10000 non-null  object
#  7   is_foreign_transaction  10000 non-null  int64
#  8   fraud                   10000 non-null  int64
# dtypes: float64(2), int64(5), object(2)
# memory usage: 703.3+ KB

# %%
# Statistiques descriptives
print("📈 Statistiques descriptives :")
df.describe()
# Out:
# 📈 Statistiques descriptives :
#        transaction_amount  transaction_hour  num_transactions_24h  \
# count        10000.000000      10000.000000           10000.00000
# mean            45.614928         11.469900               2.49840
# std             41.264072          6.910389               1.57291
# min              5.000000          0.000000               0.00000
# 25%             19.447500          5.000000               1.00000
# 50%             33.675000         12.000000               2.00000
# 75%             57.400000         17.000000               3.00000
# max            593.000000         23.000000              10.00000
#
#        account_age_days  avg_amount_30d  is_foreign_transaction         fraud
# count      10000.000000    10000.000000            10000.000000  10000.000000
# mean        2502.315700       31.161326                0.254600      0.055100
# std         1441.672572       24.688433                0.435658      0.228187
# ...

# %% [markdown]
# ## 4. Vérification des valeurs manquantes

# %%
# Compter les valeurs manquantes par colonne
missing_values = df.isnull().sum()
missing_percent = (missing_values / len(df)) * 100

# Créer un DataFrame récapitulatif
missing_df = pd.DataFrame({
    'Valeurs manquantes': missing_values,
    'Pourcentage (%)': missing_percent
})

# Afficher uniquement les colonnes avec des valeurs manquantes
missing_df = missing_df[missing_df['Valeurs manquantes'] > 0]

if len(missing_df) > 0:
    print("⚠️ Valeurs manquantes détectées :")
    print(missing_df)
else:
    print("✓ Aucune valeur manquante détectée")
# Out:
# ✓ Aucune valeur manquante détectée

# %% [markdown]
# ## 5. Distribution de la variable cible (fraud)

# %%
# Compter les fraudes et non-fraudes
fraud_counts = df['fraud'].value_counts()
fraud_percent = df['fraud'].value_counts(normalize=True) * 100

print("🎯 Distribution de la variable cible (fraud) :")
print("\nNombre :")
print(fraud_counts)
print("\nPourcentage :")
print(fraud_percent.round(2))

# Vérifier si le dataset est déséquilibré
fraud_ratio = fraud_counts[1] / fraud_counts[0]
if fraud_ratio < 0.1:
    print(f"\n⚠️ Dataset déséquilibré détecté (ratio: {fraud_ratio:.2%})")
else:
    print(f"\n✓ Dataset équilibré (ratio: {fraud_ratio:.2%})")
# Out:
# 🎯 Distribution de la variable cible (fraud) :
#
# Nombre :
# fraud
# 0    9449
# 1     551
# Name: count, dtype: int64
#
# Pourcentage :
# fraud
# 0    94.49
# 1     5.51
# Name: proportion, dtype: float64
#
# ⚠️ Dataset déséquilibré détecté (ratio: 5.83%)

# %% [markdown]
# ## 6. Aperçu des types de variables

# %%
# Séparer les colonnes numériques et catégorielles
numeric_cols = df.select_dtypes(include=[np.number]).columns.tolist()
categorical_cols = df.select_dtypes(include=['object']).columns.tolist()

print(f"📊 Variables numériques ({len(numeric_cols)}) :")
print(numeric_cols)
print(f"\n📝 Variables catégorielles ({len(categorical_cols)}) :")
print(categorical_cols)
# Out:
# 📊 Variables numériques (7) :
# ['transaction_amount', 'transaction_hour', 'num_transactions_24h', 'account_age_days', 'avg_amount_30d', 'is_foreign_transaction', 'fraud']
#
# 📝 Variables catégorielles (2) :
# ['country_risk', 'device_type']

# %% [markdown]
# ## 7. Sauvegarde des informations

# %%
# Créer un dictionnaire avec les informations clés
data_info = {
    'n_rows': df.shape[0],
    'n_columns': df.shape[1],
    'n_fraud': fraud_counts[1],
    'n_normal': fraud_counts[0],
    'fraud_percentage': fraud_percent[1],
    'columns': df.columns.tolist(),
    'numeric_columns': numeric_cols,
    'categorical_columns': categorical_cols,
    'missing_values': df.isnull().sum().sum()
}

print("✓ Résumé des données :")
for key, value in data_info.items():
    if isinstance(value, list):
        print(f"  {key}: {len(value)} éléments")
    else:
        print(f"  {key}: {value}")
# Out:
# ✓ Résumé des données :
#   n_rows: 10000
#   n_columns: 9
#   n_fraud: 551
#   n_normal: 9449
#   fraud_percentage: 5.510000000000001
#   columns: 9 éléments
#   numeric_columns: 7 éléments
#   categorical_columns: 2 éléments
#   missing_values: 0

# %% [markdown]
# ## ✅ Conclusion
#
# Les données ont été chargées avec succès. Passez au notebook suivant pour l'analyse exploratoire détaillée.
